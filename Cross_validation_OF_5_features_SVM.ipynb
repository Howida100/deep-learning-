# %% [markdown]
# <a href="https://colab.research.google.com/github/Howida100/deep-learning-/blob/master/Cross_validation_OF_5_features_SVM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#https://github.com/knathanieltucker/bit-of-data-science-and-scikit-learn/blob/master/notebooks/CrossValidation.ipynb
#https://www.youtube.com/watch?v=L_dQrZZjGDg&t=16s
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import datasets
from sklearn import svm
import pandas as pd
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-3cc6ef72-0cc2-4284-abf1-9495a70eb798" name="files[]" multiple disabled />
#      <output id="result-3cc6ef72-0cc2-4284-abf1-9495a70eb798">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving all samples 2(5).csv to all samples 2(5) (1).csv

# %%
for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
# User uploaded file "all samples 2(5).csv" with length 1509673 bytes

# %%
#Reading data from CSV file
import pandas as pd
import numpy as np
df = pd.read_csv('all samples 2(5).csv')
df
# Out:
#                                            Package  ...      lablel
# 0                                  net.iconchanger  ...     malware
# 1                        com.Jaaru.TruthorDareFree  ...     malware
# 2                             com.jrtstudio.iSyncr  ...     malware
# 3                               com.ftbsports.fmrm  ...     malware
# 4                    com.sillycube.android.Rushing  ...     malware
# 5               com.mathpad.mobile.android.wt.unit  ...     malware
# 6                                   com.tvshowfavs  ...     malware
# 7                    com.AndPhone.game.DonutKungFu  ...     malware
# 8         com.highlycaffeinatedcode.scrabblehelper  ...     malware
# 9                  com.doenter.android.vpn.fivevpn  ...     malware
# 10                           jp.co.johospace.jorte  ...     malware
# 11                    com.socialnmobile.flashlight  ...     malware
# 12                                 com.bfs.ninjump  ...     malware
# ...

# %%
#Explore null cells
df.isnull()
# Out:
#        Package  Category  ...  Your messages : receive SMS (D)  lablel
# 0        False     False  ...                            False   False
# 1        False     False  ...                            False   False
# 2        False     False  ...                            False   False
# 3        False     False  ...                            False   False
# 4        False     False  ...                            False   False
# 5        False     False  ...                            False   False
# 6        False     False  ...                            False   False
# 7        False     False  ...                            False   False
# 8        False     False  ...                            False   False
# 9        False     False  ...                            False   False
# 10       False     False  ...                            False   False
# 11       False     False  ...                            False   False
# ...

# %%
#View total of null values by column
df.isnull().sum()
# Out:
# Package                                                 0
# Category                                                0
# Default : read phone state and identity (S)             0
# Default : write contact data (S)                        0
# Your accounts : access all Google services (S)          0
# Your accounts : contacts data in Google accounts (D)    0
# Your messages : receive SMS (D)                         0
# lablel                                                  0
# dtype: int64

# %%
#if there is space Fill all null values with a space, and score that in the current data frame
df=df.fillna(" ")

# %%
# !pip install category_encoders

# %%
import category_encoders as ce
print(df.dtypes)
# Out:
# Package                                                 object
# Category                                                object
# Default : read phone state and identity (S)              int64
# Default : write contact data (S)                         int64
# Your accounts : access all Google services (S)           int64
# Your accounts : contacts data in Google accounts (D)     int64
# Your messages : receive SMS (D)                          int64
# lablel                                                  object
# dtype: object

# %%
df2 = df.copy()
df2['Package'] = df2['Package'].astype('category')
df2['Category'] = df2['Category'].astype('category')

# %%
df2['Package'] = df2['Package'].cat.codes
df2['Category'] = df2['Category'].cat.codes

# %%
df2
# Out:
#        Package  Category  ...  Your messages : receive SMS (D)      lablel
# 0        19088        18  ...                                0     malware
# 1         1345         6  ...                                0     malware
# 2         9036        16  ...                                0     malware
# 3         6819        25  ...                                0     malware
# 4        13790        25  ...                                0     malware
# 5        10286        26  ...                                0     malware
# 6        15347         9  ...                                0     malware
# 7         1140        21  ...                                0     malware
# 8         7931         2  ...                                1     malware
# 9         5522        26  ...                                0     malware
# 10       18063        20  ...                                0     malware
# ...

# %%
X = df2.loc[:, df2.columns != target]
Y = df2.loc[:, df2.columns == target]

# %%
X.shape
# Out:
# (25458, 7)

# %%
Y.shape
# Out:
# (25458, 1)

# %%
train_test_split
# Out:
# <function sklearn.model_selection._split.train_test_split>

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, 
                                                    test_size=0.3, 
                                                    random_state=0)
x_train.shape, y_train.shape
# Out:
# ((17820, 7), (17820, 1))

# %%
print('There are {} samples in the training set and {} samples in the test set'.format(x_train.shape[0], x_test.shape[0]))
# Out:
# There are 17820 samples in the training set and 7638 samples in the test set

# %%
x_test.shape, y_test.shape
# Out:
# ((7638, 7), (7638, 1))

# %%
x_test.shape, y_test.shape
# Out:
# ((7638, 7), (7638, 1))

# %%
clf = svm.SVC(kernel='linear', C=1).fit(x_train, y_train)
clf.score(x_test, y_test)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.7089552238805971

# %%
clf.score(x_train, y_train)
# Out:
# 0.7123456790123457

# %%
from sklearn.model_selection import cross_val_score

cross_val_score
# Out:
# <function sklearn.model_selection._validation.cross_val_score>

# %%
clf = svm.SVC(kernel='linear', C=1)

scores = cross_val_score(clf, X, Y, cv=2)

scores
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# array([0.34697565, 0.46315211])

# %%
print("Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))
# Out:
# Accuracy: 0.41 (+/- 0.12)

# %%
from sklearn import metrics

scores = cross_val_score(
     clf, X, Y, cv=5, scoring='f1_macro')

scores
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
from sklearn.model_selection import ShuffleSplit

ShuffleSplit
# Out:
# sklearn.model_selection._split.ShuffleSplit

# %%
n_samples = X.shape[0]

cv = ShuffleSplit(n_splits=3, test_size=0.3, random_state=0)

cross_val_score(clf, X, Y, cv=cv)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# array([0.70895522, 0.71327573, 0.71275203])

# %%
from sklearn.model_selection import cross_val_predict

cross_val_predict
# Out:
# <function sklearn.model_selection._validation.cross_val_predict>

# %%
predicted = cross_val_predict(clf, X, Y, cv=10)

predicted.shape
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
metrics.accuracy_score(Y, predicted)
# Out:
# 0.7123890329169613

# %%
from sklearn.linear_model import LassoCV
